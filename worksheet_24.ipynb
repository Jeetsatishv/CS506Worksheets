# %% [markdown]
# # Worksheet 24
#
# Name: Jeetkumar Satish Vijaywargi
# UID: U00204914
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# 2023-12-06 18:57:29.950283: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 3/3 [==============================] - 1s 4ms/step - loss: 0.6618
# Epoch 2/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6603
# Epoch 3/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6593
# Epoch 4/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6584
# Epoch 5/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6576
# Epoch 6/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6568
# Epoch 7/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6561
# Epoch 8/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6554
# Epoch 9/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6547
# Epoch 10/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6541
# Epoch 11/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6534
# Epoch 12/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6529
# Epoch 13/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6521
# Epoch 14/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6515
# Epoch 15/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6509
# Epoch 16/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6503
# Epoch 17/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6497
# Epoch 18/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6491
# Epoch 19/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6483
# Epoch 20/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6478
# Epoch 21/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6471
# Epoch 22/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6465
# Epoch 23/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6459
# Epoch 24/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6454
# Epoch 25/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6446
# Epoch 26/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6440
# Epoch 27/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6433
# Epoch 28/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6426
# Epoch 29/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6420
# Epoch 30/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6414
# Epoch 31/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6406
# Epoch 32/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6400
# Epoch 33/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6394
# Epoch 34/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6387
# Epoch 35/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6380
# Epoch 36/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6374
# Epoch 37/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6367
# Epoch 38/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6360
# Epoch 39/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6353
# Epoch 40/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6346
# Epoch 41/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6339
# Epoch 42/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6332
# Epoch 43/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6324
# Epoch 44/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6318
# Epoch 45/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6310
# Epoch 46/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6303
# Epoch 47/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6296
# Epoch 48/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6290
# Epoch 49/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6282
# Epoch 50/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6275
# Epoch 51/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6268
# Epoch 52/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6261
# Epoch 53/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6254
# Epoch 54/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6247
# Epoch 55/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6240
# Epoch 56/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6233
# Epoch 57/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6226
# Epoch 58/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6220
# Epoch 59/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.